# %%
from dotenv import load_dotenv
import os
import openai
import shutil
import PyPDF2
import openai
from pydantic import BaseModel, ValidationError, constr
from colorama import Fore, Style, init

load_dotenv(override=True)
OPENAPI_API_KEY = os.getenv("OPENAPI_API_KEY")
client = openai.Client()

class TitleModel(BaseModel):
    title: constr(min_length=1, max_length=100)

# %%
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

def get_pdf_title(pdf_text):
    # Use OpenAI Completion to extract the title
    response = client.chat.completions.create(
    model='gpt-4o-mini',
    messages=[
        {'role': 'system', 'content': 'You are a helpful assistant.'},
        {'role': 'user', 'content': f'Extract the title from the following document:\n\n{pdf_text[:2000]}\n\n Do not use only capital letters and do not include and slashes forward backward etc. Make sure the title can be used as a filename. Keep it short and concise but clear e.g. not only operating manual or annual report. Title should not be longer than 50 characters. do not use acronyms\n\nTitle:'}
    ],
    max_tokens=150
    )
    title = response.choices[0].message.content
    return title

def validate_title(title):
    try:
        validated_title = TitleModel(title=title)
        return validated_title.title
    except ValidationError as e:
        print(f"Invalid title: {e}")
        return None

def rename_and_move_pdf(folder_path, renamed_folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".pdf"):
            try:
                file_path = os.path.join(folder_path, filename)
                pdf_text = extract_text_from_pdf(file_path)
                title = get_pdf_title(pdf_text)
                
                valid_title = validate_title(title)
                if valid_title:
                    new_file_path = os.path.join(renamed_folder_path, f"{valid_title}.pdf")
                    
                    # Rename and move the file to the new folder
                    shutil.move(file_path, new_file_path)
                    print(f"Renamed and moved {filename} to {valid_title}.pdf")
                else:
                    print(f"Skipping renaming for {filename} due to invalid title.")
            except Exception as e:
                print(f"{Fore.RED}An error occurred with {filename}: {e}{Style.RESET_ALL}")
                # Continue to the next file

# Folder paths
folder_path = './papers'  # Folder containing the PDFs
renamed_folder_path = './papers/renamed'  # Folder to move renamed PDFs to

# Create the destination folder if it doesn't exist
os.makedirs(renamed_folder_path, exist_ok=True)

# Process PDFs and continue on error
try:
    rename_and_move_pdf(folder_path, renamed_folder_path)
except Exception as e:
    print(f"{Fore.RED}An error occurred: {e}{Style.RESET_ALL}")
# Out:
# Renamed and moved Das Kapital Band 1.pdf to Das Kapital Band 1.pdf
# Renamed and moved Customer Care Services RfP Zalando Fashion Store.pdf to Customer Care Services Proposal for Zalando.pdf
# Renamed and moved finetuning text-to-image diffusion models for fairness.pdf to Finetuning Text to Image Diffusion Models for Fairness.pdf
# Renamed and moved Stock Market Prediction Using Machine Learning Models.pdf to Stock Market Prediction Using Machine Learning Models.pdf
# Renamed and moved Title: ILCE-6700 Startup Guide.pdf to E-mount Interchangeable Lens Digital Camera Startup Guide.pdf
# Renamed and moved Identifying Real Estate Opportunities Using Machine Learning.pdf to Identifying Real Estate Opportunities Using Machine Learning.pdf
# Renamed and moved Self-RAG Learning to Retrieve Generate and Critique Through Self-Reflection.pdf to Self-Rag Learning to Retrieve Generate and Critique.pdf
# Renamed and moved ServiceNow Predictive Intelligence for Customer Service Management.pdf to ServiceNow Predictive Intelligence for Customer Service.pdf
# Renamed and moved improving_long_story_coherence_with_detailed_outline_control.pdf to improving long story coherence with detailed outline control.pdf
# Renamed and moved how to create a service excellence organization.pdf to How to Create a Service Excellence Organization.pdf
# Renamed and moved Herbal Therapy Is Equivalent to Rifaximin for the Treatment of Small Intestinal Bacterial Overgrowth.pdf to Herbal Therapy Is Equivalent to Rifaximin for SIBO.pdf
# Renamed and moved The Use of Artificial Intelligence in Writing Scientific Review Articles.pdf to The use of artificial intelligence in writing scientific review articles.pdf
# Renamed and moved Der Aktien- und Börsenführerschein.pdf to Der Aktien- und Börsenführerschein.pdf
# Renamed and moved Creating a Culture of Customer Service Excellence.pdf to Creating a Culture of Customer Service Excellence.pdf
# Renamed and moved The Future of Strategic Measurement Enhancing KPIs With AI.pdf to The Future of Strategic Measurement Enhancing KPIs With AI.pdf
# Renamed and moved voltaren-schmerzgel-forte-packungsbeilage.pdf to Voltaren Schmerzgel forte Packungsbeilage.pdf
# Renamed and moved improving factuality and reasoning in language models through multiagent debate.pdf to improving factuality and reasoning in language models.pdf
# Renamed and moved insightpilot_an_llm_empowered_automated_data_exploration_system.pdf to InsightPilot An LLM Empowered Automated Data Exploration System.pdf
# Renamed and moved unsupervised learning of visual features by contrasting cluster assignments.pdf to unsupervised learning of visual features by contrasting cluster assignments.pdf
# Renamed and moved The Definitive Guide to Fine-Tuning LLMs.pdf to The Definitive Guide to Fine-Tuning LLMs.pdf
# Renamed and moved large language models as optimizers.pdf to Large language models as optimizers.pdf
# Renamed and moved Ultimate Guide to Operating a Successful Coworking Space.pdf to Ultimate Guide to Operating a Successful Coworking Space.pdf
# An error occurred with 355200-sample.pdf: PyCryptodome is required for AES algorithm
# Renamed and moved Civil Complaint for Declaratory and Injunctive Relief.pdf to Civil Complaint for Declaratory and Injunctive Relief.pdf
# Renamed and moved ICLR2024_Continual_Learning_Revisited_Hessian_Approximation_Variance_Reduction.pdf to Meta Continual Learning Revisited: Enhancing Online Hessian.pdf
# Renamed and moved Tree of Thoughts Deliberate Problem Solving with Large Language Models.pdf to Tree of Thoughts Deliberate Problem Solving with Language Models.pdf
# An error occurred with ZBK_Handbuch_v24.0_Nov2020_FINAL.pdf: PyCryptodome is required for AES algorithm
# Renamed and moved HBR’s 10 Must Reads: The Essentials.pdf to HBR Must Reads on Management and Leadership.pdf
# Renamed and moved useofartificialwritingreviews.pdf to The use of artificial intelligence in writing scientific review articles.pdf
# Renamed and moved kepler90i.pdf to Identifying Exoplanets with Deep Learning Techniques.pdf
# Renamed and moved Values: A Framework for Systematic Validation of Uncertainty Estimation in Semantic Segmentation.pdf to Values: A Framework for Systematic Validation of Uncertainty Estimation in Semantic Segmentation.pdf
# Renamed and moved Title: US Involvement in the War - Internal Documents - The Kennedy Administration.pdf to U.S. Involvement in the War Internal Documents Kennedy Administration.pdf
# Renamed and moved customer-experience-analytics.pdf to Delivering Exceptional Customer Experience.pdf
# Renamed and moved Stock_Trend_Prediction_Using_News_Sentiment_Analys.pdf to Stock Trend Prediction Using News Sentiment Analysis.pdf
# incorrect startxref pointer(2)
# Renamed and moved darm_lgs_pp_vortrag_1.pdf to leaky gut syndrome and its significance.pdf
# Renamed and moved Ames, Iowa: Alternative to the Boston Housing Data as an End of Semester Regression Project.pdf to Ames Iowa Alternative to Boston Housing Data.pdf
# Renamed and moved Re3 Generating Longer Stories With Recursive Reprompting and Revision.pdf to Generating Longer Stories With Recursive Reprompting.pdf
# Renamed and moved Basisinformationen.pdf to criteria of investment decisions.pdf
# Renamed and moved REACT: SYNERGIZING REASONING AND ACTING IN LANGUAGE MODELS.pdf to ReAct: Synergizing Reasoning and Acting in Language Models.pdf
# Renamed and moved Sure! Please provide the document from which you'd like me to extract the title..pdf to Please provide the text of the document from which you would like me to extract the title..pdf
# Renamed and moved TourScanner Annual Report 2019.pdf to TourScanner Annual Report 2019.pdf
# Renamed and moved sas-can-help-you-reinvent-your-customer-interactions-111802.pdf to AI for Customer Experience Improvement.pdf
# Renamed and moved LONG LORA - EFFICIENT FINE-TUNING OF LONG -CONTEXT LARGE LANGUAGE MODELS_ICLR 2024.pdf to Long LoRA Efficient Fine-Tuning of Long Context LLMs.pdf
# Renamed and moved ICLR2024_SWE-BENCH_CanLanguageModelsResolveGitHubIssues.pdf to SWE Bench: Can Language Models Resolve Real-World GitHub Issues?.pdf
# Renamed and moved 5488_metagpt_meta_programming_for_a.pdf to MetaGPT: Meta Programming for Multi-Agent Collaboration.pdf
# Renamed and moved Capital Markets Academy Manual for Participants.pdf to Capital Markets Academy Online Event Manual.pdf
# Renamed and moved lecture1.pdf to Title: introduction to cs50 programming.pdf
# Renamed and moved 897851umDE.pdf to Washer Dryer User Information L 76680 NW.pdf
# Renamed and moved Benchmarking Financial Analysis with RetrievalAugmented Stock-Chain Framework.pdf to AlphaFin Benchmarking Financial Analysis Framework.pdf
# Renamed and moved Assignment Brief_COO_IDnow_2020_HIEC.pdf to Chief Operating Officer Specification Document.pdf
# Renamed and moved Report of the Department of the Treasury on the Bureau of Alcohol, Tobacco, and Firearms Investigation of Vernon Wayne Howell also known as David Koresh September 1993.pdf to Report on Bureau of Alcohol Tobacco and Firearms Investigation of Vernon Wayne Howell.pdf
# Renamed and moved ‘If you press this, I’ll pay’: MrBeast, YouTube, and the mobilisation of the audience commodity in the name of charity.pdf to If You Press This, I'll Pay MrBeast YouTube Charity.pdf
# Renamed and moved The Future of Strategic Measurement: Enhancing KPIs With AI.pdf to The Future of Strategic Measurement Enhancing KPIs With AI.pdf
# Renamed and moved Injecting New Knowledge into Large Language Models via Supervised Fine-Tuning.pdf to Injecting New Knowledge into Large Language Models.pdf
# Renamed and moved AutoGen: Enabling Next-Gen LLM Applications via Multi-Agent Conversation.pdf to AutoGen enabling next-gen LLM applications.pdf
# Renamed and moved LOFTQ_L_ORA-F_INE-TUNING-AWARE_QUANTIZATION_FOR_LARGE_LANGUAGE_MODELS.pdf.pdf to LoRa Fine-Tuning Aware Quantization for Language Models.pdf
# Renamed and moved metra scalable unsupervised rl with metric aware abstraction.pdf to Metric-Aware Abstraction for Unsupervised Reinforcement Learning.pdf
# Renamed and moved 125977361.pdf to Sentiment Analysis of Stocks Based on News Headlines.pdf
# Renamed and moved ICLR_2024_Knowledge_Card_Filling_LLMs_Knowledge_Gaps_With_Plug-In_Specialized_Language_Models.pdf.pdf to Knowledge Card: Filling Knowledge Gaps with Models.pdf
# Renamed and moved Preliminary Assessment Unidentified Aerial Phenomena.pdf to Preliminary Assessment of Unidentified Aerial Phenomena.pdf
# Renamed and moved Opportunities and Risks of Foundation Models.pdf to Opportunities and Risks of Foundation Models.pdf
# Renamed and moved Precise Zero-Shot Dense Retrieval without Relevance Labels.pdf to Precise Zero-Shot Dense Retrieval without Relevance Labels.pdf
# Renamed and moved Operating Manual for Audio Receiver System.pdf to Audio Receiver Operating Manual.pdf
# Renamed and moved Prolego Become an AI Company in 90 Days (1).pdf to Become an AI Company in 90 Days.pdf
# Renamed and moved 2311.09533v3.pdf to effective large language model adaptation for improved grounding and citation generation.pdf
# Renamed and moved PROPOSAL FOR UMGAWA 20191206 V1 from Stargazer .pdf to Proposal for Umgawa Zipline Eco Adventures.pdf
# Renamed and moved bericht der arbeitsgruppe kommando spezialkräfte.pdf to Report of the Working Group Special Forces.pdf
# Renamed and moved The Art of Work.pdf to The Art of Work.pdf
# Renamed and moved AI_Writing_Scientific_Review_Articles.pdf to The use of artificial intelligence in writing scientific review articles.pdf
# Renamed and moved chain of thought prompting elicits reasoning in large language models.pdf to chain of thought prompting improves reasoning in models.pdf
# Renamed and moved AI Transformations in Customer Experience.pdf to AI Transformation of Customer Experience.pdf
# Renamed and moved METAGPT: META PROGRAMMING FOR A MULTI-AGENT COLLABORATIVE FRAMEWORK.pdf to Meta GPT: Meta Programming for Multi-Agent Collaboration.pdf
# Renamed and moved ChatGPT Power Prompts Guide.pdf to Title: ChatGPT Power Prompts Guide.pdf
# Renamed and moved Bericht_17-1048-CX_PA46_Bodensee.pdf to Untersuchungsbericht Flugunfall Bodensee 2017.pdf
# Renamed and moved 1607.01958.pdf to Stock Trend Prediction Using News Sentiment Analysis.pdf
# Renamed and moved Understanding Nicotine: Its Impact on the Brain, Body, and Methods for Cessation.pdf to understanding nicotine its impact and cessation methods.pdf
# Renamed and moved SELF-CONSISTENCY IMPROVES CHAIN OF THOUGHT REASONING IN LANGUAGE MODELS.pdf to Self Consistency Improves Chain of Thought Reasoning.pdf
# Renamed and moved Self Discover Large Language Models Reasoning Structures.pdf to Self-Discover Large Language Models Reasoning Structures.pdf
# Renamed and moved KNOWLEDGE CARD: FILLING LLM S’ KNOWLEDGE GAPS WITH PLUG-IN SPECIALIZED LANGUAGE MODELS.pdf to Knowledge Card: Filling Language Models' Knowledge Gaps.pdf
# Renamed and moved FundamentalEditing.pdf to Ultimate Guide to Fundamental Editing.pdf
# Renamed and moved SELF-RAG: LEARNING TO RETRIEVE, GENERATE, AND CRITIQUE THROUGH SELF-REFLECTION.pdf to Self Reflective Retrieval Augmented Generation.pdf
# Renamed and moved quirion-factsheet-VV.VV-30.pdf to Globales Portfolio 30 Prozent Aktien 70 Prozent Anleihen.pdf
# Renamed and moved 7070-Article Text-10299-1-10-20200526.pdf to Minecraft as a Platform for Project-Based Learning in AI.pdf
# Renamed and moved SCOPE_OF_AN_RFP_(PaCa)_(1).pdf to Partner Care Project for Zalando SE.pdf
# Renamed and moved structuring-your-customer-support-organization.pdf to Structuring Your Customer Support Organization.pdf
# Renamed and moved 2401.15884.pdf to Corrective Retrieval Augmented Generation.pdf
# Renamed and moved SBW_APL_MANUAL.pdf to A Pilots Life.pdf
# Renamed and moved 2023.emnlp-industry.69.pdf to Harnessing LLMs for Temporal Data in Finance.pdf
# Renamed and moved the-good-the-bad-the-ugly.pdf to Global Customer Service Insights 2019.pdf
# Renamed and moved Temporal Data Meets LLM Explainable Financial Time Series Forecasting.pdf to Temporal Data Meets Large Language Models for Explainable Financial Time Series Forecasting.pdf
# Renamed and moved acheiving-digital-customer-service-transformation-white-pap.pdf to Achieving Digital Customer Service Transformation.pdf
# Renamed and moved Title: ZK KIN FZ OIS K.pdf to ZKKF ZIN FZ OIS K Document.pdf
# Renamed and moved 2312.10997v1.pdf to Retrieval Augmented Generation for Language Models.pdf
# Renamed and moved Zipformer: A Faster and Better Encoder for Automatic Speech Recognition.pdf to Zipformer: A Faster and Better Encoder for Automatic Speech Recognition.pdf
# Renamed and moved proyecciones de poblacion 2020 2070.pdf to proyecciones de poblacion 2020 a 2070.pdf
# Renamed and moved METAGPT Multi-Agent Collaborative Framework Preprint.pdf.pdf to MetaGPT: Meta Programming for Multi-Agent Framework.pdf
# Renamed and moved is google getting worse a longitudinal investigation of seo spam in search engines.pdf to Is Google Getting Worse? A Longitudinal Investigation.pdf
